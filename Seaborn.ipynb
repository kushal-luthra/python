# %%
# %matplotlib inline
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={"figure.figsize": (8, 6)})
np.random.seed(sum(map(ord, "palettes")))


#sns.palplot(sns.color_palette("Blue"))

# %%
current_palette = sns.color_palette()
sns.palplot(current_palette)

# %%
sns.palplot(sns.color_palette("Blues"))

sns.palplot(sns.color_palette("Blues_r")) #reverse the order

# %%
import pandas as pd #importing packages
import os as os

diamonds =pd.read_csv("https://vincentarelbundock.github.io/Rdatasets/csv/ggplot2/diamonds.csv")

# %%
diamonds=diamonds.dropna(how='any')
# Out:
# 'C:\\Users\\jai mata di\\Documents\\Python Scripts'

# %%
diamonds.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %%
diamonds.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %%
sns.distplot(diamonds.price)
# Out:
# C:\Users\jai mata di\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.kdeplot(diamonds.price, shade=True);
# Out:
# C:\Users\jai mata di\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.jointplot(x="carat", y="price", kind="hex",data=diamonds);

# %%
sns.regplot(x="carat", y="price", data=diamonds);

# %%
sns.lmplot(x="carat", y="price", hue="cut", data=diamonds);

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.lmplot(x="carat", y="price", hue="cut",col='color', data=diamonds);

# %%
sns.stripplot(x='cut',y='price',data=diamonds)

# %%
sns.stripplot(x='cut',y='price',data=diamonds,jitter=True)

# %%
sns.swarmplot(x='cut',y='price',data=diamonds)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-92-e517679abe85> in <module>()
# ----> 1 sns.swarmplot(x='cut',y='price',data=diamonds)
#
# C:\Users\jai mata di\Anaconda3\lib\site-packages\seaborn\categorical.py in swarmplot(x, y, hue, data, order, hue_order, split, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2737                        linewidth=linewidth))
#    2738
# -> 2739     plotter.plot(ax, kwargs)
#    2740     return ax
#    2741
#
# C:\Users\jai mata di\Anaconda3\lib\site-packages\seaborn\categorical.py in plot(self, ax, kws)
#    1395     def plot(self, ax, kws):
#    1396         """Make the full plot."""
# -> 1397         self.draw_swarmplot(ax, kws)
#    1398         self.add_legend_data(ax)
#    1399         self.annotate_axes(ax)
#
# ...

# %%
diamonds_2=diamonds.head(1000)

# %%
sns.stripplot(x='cut',y='price',data=diamonds_2,jitter=True)

# %%
sns.swarmplot(x='cut',y='price',data=diamonds_2)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\jai mata di\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2881, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-158-1af145283bd0>", line 1, in <module>
#     sns.swarmplot(x='cut',y='price',data=diamonds_2)
#   File "C:\Users\jai mata di\Anaconda3\lib\site-packages\seaborn\categorical.py", line 2739, in swarmplot
#     plotter.plot(ax, kwargs)
#   File "C:\Users\jai mata di\Anaconda3\lib\site-packages\seaborn\categorical.py", line 1397, in plot
#     self.draw_swarmplot(ax, kws)
#   File "C:\Users\jai mata di\Anaconda3\lib\site-packages\seaborn\categorical.py", line 1393, in draw_swarmplot
#     self.swarm_points(ax, swarm, center, width, s, **kws)
#   File "C:\Users\jai mata di\Anaconda3\lib\site-packages\seaborn\categorical.py", line 1302, in swarm_points
# ...

# %%
sns.stripplot(x='cut',y='price',data=diamonds_2,jitter=True)

# %%
diamonds_2=diamonds.query('price >1500 and price<2500')

# %%
diamonds_2.head()
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 44010   0.51  Premium     G     VS2   61.2   60.0   1546  5.17  5.12  3.15
# 44011   0.51    Ideal     G     VS2   62.9   54.0   1546  5.12  5.08  3.21
# 44012   0.51  Premium     G     VS2   62.4   57.0   1546  5.11  5.09  3.18
# 44013   0.51  Premium     G     VS2   62.7   58.0   1546  5.12  5.09  3.20
# 44014   0.51  Premium     G     VS2   62.2   57.0   1546  5.15  5.10  3.19

# %%
sns.stripplot(x='cut',y='price',data=diamonds_2)

# %%
sns.swarmplot(x='cut',y='price',hue='color',data=diamonds_2)

# %%
sns.boxplot(x='cut',y='price',hue='color',data=diamonds_2)

# %%
sns.violinplot(x='cut',y='price',hue='color',data=diamonds_2)

# %%
diamonds_2=diamonds.query('(color=="G" | color=="J") & (price > 1500 and price<2500)  ')
diamonds_2['color'].unique()

x=diamonds.query('(color=="G") & (price > 1500 and price<2500)  ')
x.head
# Out:
# <bound method NDFrame.head of        carat        cut color clarity  depth  table  price     x     y     z
# 44010   0.51    Premium     G     VS2   61.2   60.0   1546  5.17  5.12  3.15
# 44011   0.51      Ideal     G     VS2   62.9   54.0   1546  5.12  5.08  3.21
# 44012   0.51    Premium     G     VS2   62.4   57.0   1546  5.11  5.09  3.18
# 44013   0.51    Premium     G     VS2   62.7   58.0   1546  5.12  5.09  3.20
# 44014   0.51    Premium     G     VS2   62.2   57.0   1546  5.15  5.10  3.19
# 44015   0.51      Ideal     G     VS2   62.7   57.0   1546  5.12  5.05  3.19
# 44016   0.51    Premium     G     VS2   62.9   58.0   1546  5.11  5.06  3.20
# 44017   0.51    Premium     G     VS2   62.3   59.0   1546  5.10  5.07  3.17
# 44030   0.51    Premium     G     VS2   62.4   58.0   1546  5.12  5.11  3.19
# 44039   0.97       Fair     G      I1   57.2   60.0   1547  6.59  6.36  3.72
# 44043   0.61  Very Good     G     SI1   59.7   63.0   1548  5.50  5.43  3.26
# ...

# %%
sns.violinplot(x='cut',y='price',hue='color',data=diamonds_2)

# %%
sns.swarmplot(x='cut',y='price',data=diamonds_2)

# %%
sns.pointplot(x='cut',y='price',hue='color', data=diamonds_2)

# %%
sns.countplot(x='color',data=diamonds_2,palette="Greens_d")

# %%
sns.boxplot(data=diamonds_2, orient="h")
x.head()
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 44010   0.51  Premium     G     VS2   61.2   60.0   1546  5.17  5.12  3.15
# 44011   0.51    Ideal     G     VS2   62.9   54.0   1546  5.12  5.08  3.21
# 44012   0.51  Premium     G     VS2   62.4   57.0   1546  5.11  5.09  3.18
# 44013   0.51  Premium     G     VS2   62.7   58.0   1546  5.12  5.09  3.20
# 44014   0.51  Premium     G     VS2   62.2   57.0   1546  5.15  5.10  3.19

# %%
diamonds_2.head()

diamonds_2['clarity'].unique()

sns.factorplot(x='cut',y='price',hue='color', col='clarity', data=diamonds_2, kind='bar')
